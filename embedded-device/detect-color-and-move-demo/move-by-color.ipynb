# %%
import cv2
import numpy as np
import traitlets
from IPython.display import display
import ipywidgets.widgets as widgets
from jetbot import Camera, bgr8_to_jpeg
from ColorDetector import ColorDetector
from Drawbot import Drawbot
import time

# %%
drawbot = Drawbot()
camera = Camera.instance(width=224, height=224)
image = widgets.Image(format='jpeg', width=224, height=224)
color_detector = ColorDetector()
# Out:
# color detector is being initialized

# %%
camera_link = traitlets.dlink((camera, 'value'), (image, 'value'), transform=bgr8_to_jpeg)
display(widgets.VBox([widgets.HBox([image])]))

def execute(change):
    image = change['image']
#     color_name = color_detector.get_color_name(image)
    color_name = color_detector.detect_color(image)
    print(color_name)
    drawbot.step_forward()
    if color_name == "Red":
        drawbot.stop()
        drawbot.step_left()
        drawbot.wait(1.68)
        drawbot.stop()
    elif color_name == "Green":
        drawbot.stop()
        drawbot.step_left(0.4)
        drawbot.wait(5.68)
        drawbot.stop()
    elif color_name == "Blue":
        drawbot.stop()
        drawbot.step_right()
        drawbot.wait(1)
        drawbot.stop()
        
    print(color_name, end=' ')
# Out:
# VBox(children=(HBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x…

# %%
while(True):
    time.sleep(1.0)
    execute({'image': camera.value})
# Out:
# None
# None None
# None 14179
# Red
# Red None
# None 16339
# 19800
# 59214
# Blue
# Blue None
# None None
# None None
# None None
# None 62872
# Blue
# Blue None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None 72474
# Red
# Red None
# None None
# None None
# None 35374
# Red
# Red 15127
# Red
# Red 16409
# Blue
# Blue 10589
# 10181
# Blue
# Blue 80792
# 19019
# Blue
# Blue 55598
# Red
# Red 482119
# Red
# Red 124305
# Red
# Red None
# None None
# None None
# None None
# None None
# None None
# None 52400
# 366398
# Blue
# Blue 13006
# Green
# Green 36153
# Blue
# Blue None
# None 20942
# 157092
# Blue
# Blue 10210
# Blue
# Blue None
# None None
# None None
# None None
# None None
# None 21354
# Green
# Green None
# None None
# None 66378
# Blue
# Blue None
# None 147379
# Green
# Green 10585
# Green
# Green 20050
# Blue
# Blue None
# None None
# None None
# None None
# None None
# None 1720331
# Red
# Red None
# None None
# None None
# None None
# None None
# None 11773
# Green
# Green 15972
# Green
# Green 10832
# Blue
# Blue None
# None None
# None None
# None None
# None None
# None 2622359
# Blue
# Blue None
# None 363059
# Red
# Red None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None 11642
# Green
# Green None
# None None
# None 61808
# Green
# Green None
# None None
# None None
# None None
# None 6681428
# Red
# Red None
# None None
# None None
# None 86589
# 29490
# Blue
# Blue 13999
# Blue
# Blue None
# None None
# None 21755
# Red
# Red None
# None None
# None 28545
# Green
# Green None
# None 70173
# 30288
# Blue
# Blue None
# None 18635
# Green
# Green None
# None None
# None 10227
# Blue
# Blue None
# None None
# None None
# None None
# None None
# None

# %%
drawbot.stop()

# %% [markdown]
# #

# %% [markdown]
# #####
